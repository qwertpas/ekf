# %%
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib widget




df = pd.read_csv("cartpole_log_n0.1.csv")

plt.figure(figsize=(10, 6))
plt.plot(df.x)
plt.plot(df.x_est)
plt.plot(df.x_obs)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
